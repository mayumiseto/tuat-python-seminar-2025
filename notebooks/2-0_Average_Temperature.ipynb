# %% [markdown]
# # 第1問：日本の夏は毎年熱くなっているのか？ 〜東京の1980 - 2020年の8月の平均気温を求め、可視化してみよう。

# %% [markdown]
# # Step 1: 数値や文字の扱いを理解しよう。
# - 1-1. 変数とデータ型
# - 1-2. 型変換
# - 1-3. コメントアウトとエラーメッセージ
#
# # Step 2: データ群の扱いを理解しよう。
# - 2-1. リスト/配列の基本
# - 2-2. 繰り返し処理(for文)
# - 2-3. 平均値の計算と関数 (sum, len関数)
#
# # Step 3: ファイル入出力について理解しよう。
# 3-1. テキストファイルの読み書き（open, read, write関数）
# 3-2. CSVファイルの読み書き（csvモジュールのインストール）
# 3-3. 実データを読み込んで平均水温を求める
# 3-4. 計算結果のCSVファイルへの出力
#
# # Step 4: Step 3で得られた結果を可視化しよう。
# 4-1. 可視化ライブラリを理解しよう（matplotlibの導入)
# 4-2. 軸ラベル・タイトル・デザインを整えよう
# 4-3. グラフから傾向を読み取ろう
# 4-4. グラフを保存しよう
